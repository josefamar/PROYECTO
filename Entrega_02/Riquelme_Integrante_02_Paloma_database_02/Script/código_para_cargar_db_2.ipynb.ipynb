# %%
# 1. Importar librerías
import pandas as pd

# 2. Montar Google Drive
from google.colab import drive
drive.mount('/content/drive')

# 3. Definir rutas de los CSV
ruta_base = "/Base_unificada.csv"
ruta_edad = "/Por_Edad.csv"
ruta_horario = "/Por_Horario.csv"
ruta_dia = "/Por_Dia.csv"

# 4. Cargar cada archivo en un DataFrame
df_base = pd.read_csv(ruta_base)
df_edad = pd.read_csv(ruta_edad)
df_horario = pd.read_csv(ruta_horario)
df_dia = pd.read_csv(ruta_dia)

# 5. Mostrar las primeras filas de cada base
print("Base unificada:")
display(df_base.head())

print("\nPor Edad:")
display(df_edad.head())

print("\nPor Horario:")
display(df_horario.head())

print("\nPor Día:")
display(df_dia.head())
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Base unificada:
#        Categoria  Fallecidos  Graves  Menos graves  Leves  Total lesionados  \
# 0    0 a 14 años           0       0             0      2                 2
# 1   15 a 29 años           4       3             4      6                13
# 2   30 a 44 años           7       9             3      3                13
# 3   45 a 59 años           7      12             0      5                20
# 4  60 años y más           2       3             0      4                 7
#
#    Indice severidad Fuente
# 0               NaN   Edad
# 1               NaN   Edad
# 2               NaN   Edad
# 3               NaN   Edad
# 4               NaN   Edad
# Por Edad:
#             Edad      Grupo etario  Participantes  Fallecidos  Graves  \
# 0    0 a 14 años             Niños              2           0       0
# 1   15 a 29 años           Jóvenes             32           4       3
# 2   30 a 44 años   Adultos jóvenes             66           7       9
# 3   45 a 59 años           Adultos             70           7      12
# 4  60 años y más  Personas mayores             31           2       3
#
#    Menos graves  Leves  Total lesionados
# 0             0      2                 2
# 1             4      6                13
# 2             3      3                13
# 3             0      5                20
# 4             0      4                 7
# Por Horario:
#        Horario  Siniestros ferroviarios  Fallecidos  Graves  Menos graves  \
# 0  00:00-02:59                        7           3      10             1
# 1  03:00-05:59                        4           2       0             1
# 2  06:00-08:59                       12           4       2             0
# 3  09:00-11:59                       18           2       6             0
# 4  12:00-14:59                       14           3       1             0
#
#    Leves  Total lesionados  Indice severidad
# 0      1                12             42.86
# 1      0                 1             50.00
# 2      3                 5             33.33
# 3      1                 7             11.11
# 4      5                 6             21.43
# Por Día:
#          Día  Siniestros ferroviarios  Fallecidos  Graves  Menos graves  \
# 0      Lunes                       16           1       9             0
# 1     Martes                       15           4       2             2
# 2  Miércoles                       15           5       5             3
# 3     Jueves                       19           7       7             1
# 4    Viernes                       12           6       0             0
#
#    Leves  Total lesionados  Indice severidad
# 0      2                11              6.25
# 1      1                 5             26.67
# 2      1                 7             33.33
# 3      4                14             36.84
# 4      4                 4             50.00
