# %%
import pandas as pd

# %%
df2=pd.read_csv("/datoslimpios1.csv")

# %%
df2
# Out:
#     Nº EFE  Nº Nombre del cruce Artículo regulador Clase Vía   Visibilidad  \
# 0      139   1              S/N        No regulado         C  Insuficiente
# 1      140   2              S/N        No regulado         C  Insuficiente
# 2      141   3              S/N        No regulado         C    Suficiente
# 3      142   4        Lo Espejo      1º y Paso Inf       NaN           NaN
# 4      143   5       Las Ovejas                 1º         C  Insuficiente
# 5      144   6        Lo Blanco                 1º         C  Insuficiente
# 6      145   7         La Selva                 1º         C  Insuficiente
# 7      146   8              S/N        No regulado         C    Suficiente
# 8      147   9              Nos                 1º         C  Insuficiente
# 9      148  10       El Recurso                 1º         C  Insuficiente
# 10     149  11      Los Guindos                 1º         C  Insuficiente
# ...
